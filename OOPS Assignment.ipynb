# %% [markdown]
# # Python OOPs Assignment Questions and Answer

# %% [markdown]
# ## Python OOPs Questions

# %% [markdown]
# ### Q1. What is Object-Oriented Programming (OOP)?
#
# --->
# **Object-Oriented Programming (OOP)** is a programming paradigm based on the concept of **"objects"**, which are instances of **classes**.
# It allows developers to structure programs using **real-world entities** like data and behavior, by bundling them together.
#
# OOP promotes code **modularity, reusability, scalability**, and **maintainability**.
#
# ---
#
# ### 🔑 Key Features of OOP:
# 1. **Class** – Blueprint for creating objects.
# 2. **Object** – Instance of a class.
# 3. **Encapsulation** – Wrapping data and methods into a single unit.
# 4. **Inheritance** – Deriving new classes from existing ones.
# 5. **Polymorphism** – Same operation behaves differently on different classes.
# 6. **Abstraction** – Hiding unnecessary implementation details from the user.
#
# ---
#
# ### 📌 Real-Life Example in Python:
# class Student:
#     def __init__(self, name):
#         self.name = name
#
#     def study(self):
#         print(f"{self.name} is studying OOP.")
#
# ### Creating object
#     s1 = Student("Alice")
#     s1.study()  # Output: Alice is studying OOP.

# %% [markdown]
# ### Q2. What is a class in OOP?
#
# ---> A **class** in Object-Oriented Programming (OOP) is a **blueprint** or **template** for creating objects.
# It defines the **attributes (data)** and **methods (functions)** that the objects created from the class will have.
#
# A class does **not hold data itself**, but defines **how the data and behavior** of its instances (objects) should look.
#
# ---
#
# ### 🔧 Key Points:
# - A class defines **what an object is and what it can do**.
# - It allows **code reusability** by creating multiple objects from the same class.
# - Objects are created using the class by calling it like a function.
#
# ---
# ### Defining a class
#     class Car:
#       def __init__(self, brand, color):
#           self.brand = brand
#           self.color = color
#
#     def drive(self):
#         print(f"The {self.color} {self.brand} is driving.")
#
# ### Creating an object from the class
#     my_car = Car("Toyota", "Red")
#     my_car.drive()  # Output: The Red Toyota is driving.

# %% [markdown]
# ### Q3. What is an object in OOP?
#
# --> An **object** in Object-Oriented Programming (OOP) is an **instance** of a class.
# It is a real-world entity that contains both **data** (attributes) and **functions** (methods) that operate on that data.
#
# Objects are created based on the blueprint provided by a class, and each object can hold different values for its attributes.
#
# ---
#
# ### EXAMPLE :-
# #### Defining a class
#     class Dog:
#       def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     def bark(self):
#         print(f"{self.name} is barking.")
#
# ### Creating an object (instance) of the Dog class
#     my_dog = Dog("Buddy", 3)
#     my_dog.bark()  # Output: Buddy is barking.

# %% [markdown]
# ### Q4. What is the difference between abstraction and encapsulation?
#
# | Feature         | Abstraction                                     | Encapsulation                                  |
# |-----------------|-------------------------------------------------|------------------------------------------------|
# | **Definition**  | Hiding the internal details and showing only the functionality | Hiding the internal data by wrapping it inside a class |
# | **Focus**       | On **what** an object does                      | On **how** it does it                          |
# | **Purpose**     | To **reduce complexity** and allow focus on high-level design | To **protect data** and maintain control       |
# | **Example**     | Using a method like `.predict()` in a model without knowing internal logic | Making variables private using `__var` and accessing via getters/setters |
# | **Implementation** | Achieved using abstract classes or interfaces (via ABC module) | Achieved using private/public/protected access modifiers |
# | **Real-World Example** | A coffee machine—you just press a button to make coffee, not knowing the internal process | A capsule—you can’t see the contents directly, it’s sealed |
#
# ---
#
# ## ✅ Summary:
# - **Abstraction = Hiding implementation complexity**
# - **Encapsulation = Hiding data for security and structure**
#
# > 💡 In Python, we use **Abstract Base Classes (ABC)** for abstraction and use **underscore prefixes (`_var`, `__var`)** for encapsulation.

# %% [markdown]
# ### Q5. What are dunder methods in Python?
#
# **Dunder methods** (short for **Double UNDerscore methods**) are special methods in Python that have **double underscores** before and after their names — like `__init__`, `__str__`, `__len__`, etc.
#
# They are also known as:
#
# - 🔁 **Magic methods**
# - 🧠 **Special methods**
#
# ---
#
# ## 💡 Purpose:
# They are used to **customize the behavior of built-in Python operations** (like printing, adding, comparing, etc.) for your own classes.
#
# ---
#
# ## 🧪 Examples of Common Dunder Methods:
#
# | Dunder Method     | Description                                 | Example Usage        |
# |-------------------|---------------------------------------------|----------------------|
# | `__init__()`      | Constructor, runs when object is created    | `MyClass()`          |
# | `__str__()`       | Returns string version of object            | `print(obj)`         |
# | `__len__()`       | Returns length of an object                 | `len(obj)`           |
# | `__add__()`       | Defines behavior for `+` operator           | `obj1 + obj2`        |
# | `__getitem__()`   | Allows indexing like lists/dictionaries     | `obj[key]`           |
#
# ---
#
# ### ✅ Example in Python:
#
# ```python
# class Student:
#     def __init__(self, name):
#         self.name = name
#
#     def __str__(self):
#         return f"Student name is {self.name}"
#
#     def __len__(self):
#         return len(self.name)
#
# s = Student("Sarvan")
# print(s)         # Calls __str__
# print(len(s))    # Calls __len__

# %% [markdown]
# ### Q6. Explain the concept of inheritance in OOP.
# **Inheritance** is an OOP concept where a **child class (derived class)** inherits the **properties and behaviors (methods)** of a **parent class (base class)**.
#
# It promotes **code reusability** and makes it easy to create a **hierarchical structure** of classes.
#
# ---
#
# ### 🔗 Types of Inheritance in Python:
#
# | Type             | Description                                |
# |------------------|--------------------------------------------|
# | **Single**       | One child inherits from one parent         |
# | **Multiple**     | One child inherits from multiple parents   |
# | **Multilevel**   | Inheritance through multiple levels        |
# | **Hierarchical** | Multiple children inherit from one parent  |
# | **Hybrid**       | Combination of two or more above types     |
#
# ---
#
# ## ✅ Basic Example (Single Inheritance):
#
# ```python
# class Animal:
#     def speak(self):
#         return "I am an animal"
#
# class Dog(Animal):  # Dog inherits from Animal
#     def bark(self):
#         return "Woof!"
#
# d = Dog()
# print(d.speak())  # Inherited from Animal
# print(d.bark())   # Defined in Dog

# %% [markdown]
# ### Q7. What is polymorphism in OOP?
# **Polymorphism** means **"many forms"**. In OOP, it allows objects of **different classes** to be **treated as objects of a common superclass**, especially when they share the **same method name** but behave **differently**.
#
# ---
#
# #### 🔑 Types of Polymorphism in Python:
#
# | Type                     | Description                                           |
# |--------------------------|-------------------------------------------------------|
# | **Compile-Time (Overloading)** | Same method name with different arguments *(not natively supported in Python)* |
# | **Run-Time (Overriding)**       | Subclass provides specific implementation of a method from the parent class |
#
# ---
#
# #### ✅ Real-Life Analogy:
# Imagine a method called `make_sound()`:
#
# - 🐶 A **Dog** barks (`Woof!`)
# - 🐱 A **Cat** meows (`Meow!`)
# - 🐄 A **Cow** moos (`Moo!`)
#
# They all implement the same method name but behave differently — that's **polymorphism**!
#
# ---
#
# #### 🧪 Example in Python:
#
# ```python
# class Animal:
#     def speak(self):
#         return "Some sound"
#
# class Dog(Animal):
#     def speak(self):
#         return "Woof!"
#
# class Cat(Animal):
#     def speak(self):
#         return "Meow!"
#
# # Polymorphism in action
# animals = [Dog(), Cat()]
# for animal in animals:
#     print(animal.speak())  # Calls appropriate method based on object

# %% [markdown]
# ### Q8. How is encapsulation achieved in Python?
#
# **Encapsulation** is an OOP principle where we **bundle data (variables)** and the **methods** that operate on that data into a single unit — usually a **class**.
#
# It also helps to **restrict access** to some components, making the code more secure and robust.
#
# ---
#
# #### 🧰 How Python Implements Encapsulation:
#
# | Access Modifier | Syntax        | Meaning                              |
# |------------------|----------------|--------------------------------------|
# | Public           | `self.name`    | Accessible from anywhere             |
# | Protected        | `_name`        | Meant for internal use (convention)  |
# | Private          | `__name`       | Name mangled, not accessible directly |
#
# ---
#
# ## ✅ Example:
#
# ```python
# class BankAccount:
#     def __init__(self, owner, balance):
#         self.owner = owner        # Public
#         self._bank_name = "SBI"   # Protected (by convention)
#         self.__balance = balance  # Private
#
#     def deposit(self, amount):
#         if amount > 0:
#             self.__balance += amount
#
#     def get_balance(self):
#         return self.__balance
#
# account = BankAccount("Sarvan", 10000)
# print(account.owner)        # ✅ Accessible
# print(account._bank_name)   # ⚠️ Accessible but not recommended
# # print(account.__balance)  # ❌ Error: Not directly accessible
# print(account.get_balance()) # ✅ Access via method

# %% [markdown]
# ### Q9. What is a constructor in Python?
#
# A **constructor** in Python is a **special method** used to **automatically initialize an object** when it is created from a class.
#
# In Python, the constructor is defined using the method:
# ```python
# __init__(self)
# ```

# %% [markdown]
# ### Q10. What are class and static methods in Python?
#
# ### 📌 1. Class Method
#
# - Defined using the `@classmethod` decorator.
# - Takes `cls` as the **first argument** (not `self`).
# - Can access or modify **class-level variables**.
#
# ### ✅ Example:
#
# ```python
# class University:
#     uni_name = "Chitkara University"
#
#     @classmethod
#     def get_university(cls):
#         return cls.uni_name
#
# print(University.get_university())

# %% [markdown]
# ### Q11. What is method overloading in Python?
#
# **Method Overloading** is the ability to define **multiple methods with the same name** but **different number or types of parameters**.
#
# > ✅ While traditional overloading like in Java/C++ is **not supported** in Python, we can achieve **similar behavior using default arguments or `*args`**.
#
# ---
#
# #### 🔧 Why Overloading Isn't Native in Python?
#
# In Python, **the latest defined method** with the same name overrides the previous one.
#
# ```python
# class Demo:
#     def show(self, a):
#         print("One argument:", a)
#
#     def show(self, a, b):  # This overrides the previous 'show'
#         print("Two arguments:", a, b)
#
# obj = Demo()
# obj.show(1, 2)  # Works
# # obj.show(1)   ❌ Error: Missing 1 required argument

# %% [markdown]
# ### Q12. What is method overriding in OOP?
#
# **Method Overriding** allows a **child class** to **provide a specific implementation** of a method that is **already defined in its parent class**.
#
# > When a method in a subclass has the **same name, parameters, and behavior**, it overrides the parent’s method.
#
# ---
#
# #### ✅ Why Use It?
# - To **customize or extend** the behavior of a parent class method.
# - It supports **runtime polymorphism** in OOP.
#
# ---
#
# #### 🚀 Example:
#
# ```python
# class Animal:
#     def speak(self):
#         print("Animal speaks")
#
# class Dog(Animal):
#     def speak(self):  # Overriding the speak method
#         print("Dog barks")
#
# d = Dog()
# d.speak()  # Outputs: Dog barks

# %% [markdown]
# ### Q13.  What is a property decorator in Python?
#
# The `@property` decorator is used to **define a method as a read-only attribute**.
#
# > It lets you **access a method like an attribute**, without using parentheses `()`.
#
# ---
#
# #### ✅ Why Use `@property`?
#
# - Encapsulate private variables
# - Control access to attributes (like a getter)
# - Make code **cleaner and more Pythonic**
#
# ---
#
# #### 🚀 Example:
#
# ```python
# class Circle:
#     def __init__(self, radius):
#         self._radius = radius
#
#     @property
#     def area(self):
#         return 3.14 * self._radius ** 2
#
# c = Circle(5)
# print(c.area)  # Notice: No parentheses!

# %% [markdown]
# ### Q14. Why is polymorphism important in OOP?
#
# **Polymorphism** means **"many forms."**
# In OOP, it allows objects of **different classes** to be treated **as if they are objects of the same class**, using a **common interface**.
#
# ---
#
# #### 🚀 Importance of Polymorphism:
#
# #### ✅ 1. **Code Reusability**
# - Write functions or methods that work on objects of different classes.
# - Avoid code duplication.
#
# ```python
# class Dog:
#     def speak(self):
#         return "Bark"
#
# class Cat:
#     def speak(self):
#         return "Meow"
#
# def animal_sound(animal):
#     print(animal.speak())
#
# animal_sound(Dog())
# animal_sound(Cat())

# %% [markdown]
# ### Q15. What is an abstract class in Python?
#
# An **abstract class** is a **blueprint** for other classes. It **cannot be instantiated** and may contain **abstract methods** (methods with no implementation).
#
# > ✅ Used when you want to force **subclasses** to implement specific methods.
#
# ---
#
# ## 🔧 Module Required:
# Python provides `ABC` (Abstract Base Classes) through the built-in **`abc` module**.
#
# ---
#
# #### 🧪 Example:
#
# ```python
# from abc import ABC, abstractmethod
#
# class Shape(ABC):
#     @abstractmethod
#     def area(self):
#         pass  # No implementation here
#
# class Circle(Shape):
#     def __init__(self, radius):
#         self.radius = radius
#
#     def area(self):
#         return 3.14 * self.radius ** 2
#
# # s = Shape()  ❌ Error: Can't instantiate abstract class
# c = Circle(5)
# print(c.area())  # ✅ Outputs: 78.5

# %% [markdown]
# ### Q16. What are the advantages of OOP?
#
# Object-Oriented Programming (OOP) organizes code using **objects and classes**, making software design more **modular, reusable, and maintainable**.
#
# ---
#
# #### ✅ 1. **Modularity**
# - Code is divided into independent **classes and objects**.
# - Easier to develop, debug, and test.
#
# ---
#
# #### ♻️ 2. **Reusability**
# - Use **inheritance** to reuse code from existing classes.
# - Reduces duplication and development time.
#
# ---
#
# #### 🔒 3. **Encapsulation**
# - Keeps data **safe from outside interference**.
# - Internal object details are hidden, promoting clean interfaces.
#
# ---
#
# #### 🧬 4. **Inheritance**
# - Child classes **inherit properties and methods** from parent classes.
# - Promotes code hierarchy and avoids redundancy.
#
# ---
#
# #### 🔁 5. **Polymorphism**
# - Same interface, **multiple implementations**.
# - Enables flexible and dynamic code.
#
# ---
#
# #### ⚙️ 6. **Abstraction**
# - Focus on **what an object does** instead of how it does it.
# - Simplifies complex reality by modeling relevant data only.
#
# ---
#
# #### 🧠 Real-World Analogy:
#
# > Think of a **car**:
# > - You drive (interface), without knowing how the engine works (abstraction).
# > - It has components like engine, tires, etc. (modularity).
# > - You can create new cars by extending base features (inheritance).
# > - Different car models can use the same `start()` method but behave differently (polymorphism).
#
# ---
#
# ####📌 Summary Table:
#
# | Feature        | Advantage                             |
# |----------------|----------------------------------------|
# | Modularity     | Easier maintenance and collaboration   |
# | Reusability    | Reduces redundancy                     |
# | Encapsulation  | Protects data and improves security    |
# | Inheritance    | Builds relationships and code reuse    |
# | Polymorphism   | Code flexibility and simplicity        |
# | Abstraction    | Focus on essential features            |
#
# > ✅ OOP is key to **building large-scale, efficient, and readable software systems**.
# """)

# %% [markdown]
# ### Q17. What is the difference between a class variable and an instance variable?
#
# - **Class Variable**:
#   - Shared across **all instances** of the class.
#   - Defined **inside the class**, but **outside any methods**.
#
# - **Instance Variable**:
#   - **Unique for each object**.
#   - Defined inside a method using `self.` (usually in `__init__()`).
#
# ---
#
# #### 🚀 Example:
#
# ```python
# class Student:
#     school_name = "Chitkara University"  # Class Variable
#
#     def __init__(self, name, roll_no):
#         self.name = name          # Instance Variable
#         self.roll_no = roll_no    # Instance Variable
#
# s1 = Student("Sarvan", 101)
# s2 = Student("Aman", 102)
#
# print(s1.school_name)  # Chitkara University
# print(s2.school_name)  # Chitkara University
#
# s1.name = "Yaduvanshi"
# print(s2.name)  # Aman (unchanged)

# %% [markdown]
# ### Q18. What is multiple inheritance in Python?
#
# **Multiple Inheritance** is when a **class inherits from more than one parent class**.
#
# > 🔁 The child class gets access to all the **attributes and methods** of its parent classes.
#
# ---
#
# #### 🔧 Syntax & Example:
#
# ```python
# class Father:
#     def skills(self):
#         return "Gardening, Driving"
#
# class Mother:
#     def skills(self):
#         return "Cooking, Painting"
#
# class Child(Father, Mother):
#     def skills(self):
#         return f"{Father.skills(self)} & {Mother.skills(self)} + Python"
#
# c = Child()
# print(c.skills())
# # Output: Gardening, Driving & Cooking, Painting + Python

# %% [markdown]
# ### 19. H Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
#
# Both `__str__` and `__repr__` are **dunder (double underscore)** methods used to define **string representations** of objects.
#
# ---
#
# #### 🔍 `__str__()` – User-Friendly Output
#
# - Called by `print()` or `str(object)`
# - Meant for **readable output**
# - Should return a **nicely formatted string**
#
# ```python
# def __str__(self):
#     return "User-friendly output"

# %% [markdown]
# ### Q20. What is the significance of the ‘super()’ function in Python?
#
# `super()` is a **built-in function** used to **call methods from a parent (super) class**.
#
# > ✅ It helps avoid redundancy and ensures that the correct method is called in complex inheritance scenarios.
#
# ---
#
# #### 🔧 Basic Usage:
#
# ```python
# class Person:
#     def __init__(self, name):
#         self.name = name
#
# class Student(Person):
#     def __init__(self, name, roll_no):
#         super().__init__(name)  # Call parent constructor
#         self.roll_no = roll_no

# %% [markdown]
# ### Q21. MH What is the significance of the __del__ method in Python?
#
# The `__del__` method is a **destructor** method in Python.
#
# > It is **automatically called when an object is about to be destroyed**, i.e., when it goes out of scope or is deleted using `del`.
#
# ---
#
# #### 🔥 Purpose of `__del__`:
#
# - Used to **free resources** like files, network connections, or memory
# - Acts like a **cleanup hook**
# - Helpful in **resource management**
#
# ---
#
# #### 🧪 Example:
#
# ```python
# class FileManager:
#     def __init__(self, filename):
#         self.filename = filename
#         self.file = open(filename, 'w')
#         print(f"File '{filename}' opened.")
#
#     def __del__(self):
#         self.file.close()
#         print(f"File '{self.filename}' closed.")
#
# fm = FileManager("example.txt")
# del fm  # Triggers __del__()

# %% [markdown]
# ### Q22.  What is the difference between @staticmethod and @classmethod in Python?
# Both are decorators used to define methods that are **not regular instance methods**, but they serve **different purposes**.
#
# ---
#
# #### 🛠️ `@staticmethod`
#
# - Doesn’t take `self` or `cls` as a first parameter
# - Cannot access or modify class or instance state
# - Just behaves like a **normal function** inside the class
#
# ```python
# class MathTools:
#     @staticmethod
#     def add(a, b):
#         return a + b
#
# print(MathTools.add(3, 5))  # Output: 8

# %% [markdown]
# ### Q23. How does polymorphism wfrom IPython.display import Markdown
#
# **Polymorphism** means **"many forms"** — it allows objects of different classes to be treated as objects of a **common superclass**.
#
# > ✅ In Python, polymorphism lets you **call the same method** on objects of different classes and get **class-specific behavior**.
#
# ---
#
# #### 🧬 How it Works with Inheritance:
#
# ```python
# class Animal:
#     def speak(self):
#         return "Some sound"
#
# class Dog(Animal):
#     def speak(self):
#         return "Bark"
#
# class Cat(Animal):
#     def speak(self):
#         return "Meow"
#
# # Polymorphism in action
# animals = [Dog(), Cat(), Animal()]
#
# for animal in animals:
#     print(animal.speak())
# ork in Python with inheritance?

# %% [markdown]
# ### Q24. What is method chaining in Python OOP?
# **Method chaining** is a technique in Object-Oriented Programming where multiple methods are called **sequentially on the same object** in a single line.
#
# > Each method returns the object itself (`self`) so the next method can be called immediately.
#
# ---
#
# #### 🧪 Example:
#
# ```python
# class Calculator:
#     def __init__(self, value=0):
#         self.value = value
#
#     def add(self, num):
#         self.value += num
#         return self  # returning self for chaining
#
#     def subtract(self, num):
#         self.value -= num
#         return self
#
#     def multiply(self, num):
#         self.value *= num
#         return self
#
#     def show(self):
#         print("Result:", self.value)
#         return self
#
# # Method chaining in action
# calc = Calculator()
# calc.add(10).subtract(2).multiply(3).show()

# %% [markdown]
# ### Q25. What is the purpose of the __call__ method in Python?
#
# #### 📌 What is `__call__`?
#
# The `__call__` method makes **an object behave like a function**.
#
# > ✅ When you define `__call__` in a class, you can "call" the object just like you’d call a function.
#
# ---
#
# #### 🧪 Example:
#
# ```python
# class Greet:
#     def __init__(self, name):
#         self.name = name
#
#     def __call__(self):
#         print(f"Hello, {self.name}!")
#
# g = Greet("Sarvan")
# g()  # This calls the __call__ method

# %% [markdown]
# ## Practical Questions

# %%
# Q1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

# Parent class
class Animal:
    def speak(self):
        print("The animal makes a sound.")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")

# Testing the classes
generic_animal = Animal()
generic_animal.speak()

dog = Dog()
dog.speak()
# Out:
# The animal makes a sound.
# Bark!

# %%
# Q2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

from abc import ABC, abstractmethod
import math

# Abstract base class
class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

# Circle class derived from Shape
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Rectangle class derived from Shape
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Creating objects and testing
circle = Circle(5)
rectangle = Rectangle(4, 6)

print(f"Area of Circle: {circle.area():.2f}")
print(f"Area of Rectangle: {rectangle.area()}")
# Out:
# Area of Circle: 78.54
# Area of Rectangle: 24

# %%
# Q3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def show_type(self):
        print(f"Vehicle Type: {self.vehicle_type}")

# First-level derived class
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def show_brand(self):
        print(f"Brand: {self.brand}")

# Second-level derived class
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery_capacity = battery_capacity

    def show_battery(self):
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Create object of ElectricCar
tesla = ElectricCar("Four Wheeler", "Tesla", 100)

# Call methods from all levels
tesla.show_type()
tesla.show_brand()
tesla.show_battery()
# Out:
# Vehicle Type: Four Wheeler
# Brand: Tesla
# Battery Capacity: 100 kWh

# %%
# Q4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method

# Base class
class Bird:
    def fly(self):
        print("Birds can fly.")

# Derived class Sparrow
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky.")

# Derived class Penguin
class Penguin(Bird):
    def fly(self):
        print("Penguins can't fly, they swim instead!")

# Function to demonstrate polymorphism
def bird_fly_test(bird_obj):
    bird_obj.fly()

# Create objects
sparrow = Sparrow()
penguin = Penguin()

# Polymorphic behavior
bird_fly_test(sparrow)
bird_fly_test(penguin)
# Out:
# Sparrow flies high in the sky.
# Penguins can't fly, they swim instead!

# %%
# Q5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance

class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount}")
        else:
            print("Invalid deposit amount!")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: ${amount}")
        else:
            print("Invalid or insufficient funds!")

    def get_balance(self):
        print(f"Current Balance: ${self.__balance}")

account = BankAccount(100)

account.deposit(50)
account.withdraw(30)
account.get_balance()
# Out:
# Deposited: $50
# Withdrawn: $30
# Current Balance: $120

# %%
# Q6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# Base class
class Instrument:
    def play(self):
        print("Instrument is playing sound.")

# Derived class Guitar
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar 🎸")

# Derived class Piano
class Piano(Instrument):
    def play(self):
        print("Playing the piano 🎹")

def start_playing(instrument):
    instrument.play()

guitar = Guitar()
piano = Piano()

start_playing(guitar)
start_playing(piano)
# Out:
# Strumming the guitar 🎸
# Playing the piano 🎹

# %%
# Q7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

sum_result = MathOperations.add_numbers(10, 5)
print("Sum:", sum_result)

diff_result = MathOperations.subtract_numbers(10, 5)
print("Difference:", diff_result)
# Out:
# Sum: 15
# Difference: 5

# %%
# Q8. Implement a class Person with a class method to count the total number of persons created.

class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        print(f"Total Persons Created: {cls.count}")

p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

Person.total_persons()
# Out:
# Total Persons Created: 3

# %%
# Q9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

f1 = Fraction(3, 4)
f2 = Fraction(7, 2)

print("First fraction:", f1)
print("Second fraction:", f2)
# Out:
# First fraction: 3/4
# Second fraction: 7/2

# %%
# Q10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(4, 5)

result = v1 + v2

print("Vector 1:", v1)
print("Vector 2:", v2)
print("Sum:", result)
# Out:
# Vector 1: Vector(2, 3)
# Vector 2: Vector(4, 5)
# Sum: Vector(6, 8)

# %%
# Q11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p1 = Person("Alice", 25)
p1.greet()
# Out:
# Hello, my name is Alice and I am 25 years old.

# %%
# Q12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)

s1 = Student("John", [85, 90, 78, 92])

print(f"{s1.name}'s average grade is: {s1.average_grade():.2f}")
# Out:
# John's average grade is: 86.25

# %%
# Q13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width
rect = Rectangle()
rect.set_dimensions(5, 3)

print("Area of rectangle:", rect.area())
# Out:
# Area of rectangle: 15

# %%
# Q14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# Base class
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

# Derived class
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

emp = Employee("Alice", 40, 20)
mgr = Manager("Bob", 40, 30, 500)

print(f"{emp.name}'s salary: ${emp.calculate_salary()}")
print(f"{mgr.name}'s salary (with bonus): ${mgr.calculate_salary()}")
# Out:
# Alice's salary: $800
# Bob's salary (with bonus): $1700

# %%
# Q15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# Creating a Product object
item = Product("Laptop", 75000, 2)

print(f"Total price for {item.quantity} {item.name}(s): ₹{item.total_price()}")
# Out:
# Total price for 2 Laptop(s): ₹150000

# %%
# Q16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"

cow = Cow()
sheep = Sheep()

print("Cow sound:", cow.sound())
print("Sheep sound:", sheep.sound())
# Out:
# Cow sound: Moo
# Sheep sound: Baa

# %%
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}."

book = Book("To Kill a Mockingbird", "Harper Lee", 1960)

print(book.get_book_info())
# Out:
# 'To Kill a Mockingbird' by Harper Lee, published in 1960.

# %%
# Q18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

my_mansion = Mansion("123 Royal Lane, Beverly Hills", 25000000, 10)

# Displaying details
print("Address:", my_mansion.address)
print("Price: ₹", my_mansion.price)
print("Number of Rooms:", my_mansion.number_of_rooms)
# Out:
# Address: 123 Royal Lane, Beverly Hills
# Price: ₹ 25000000
# Number of Rooms: 10
